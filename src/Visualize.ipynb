# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import rasterio

# %%
parent = r"D:\ForestFire\CBH\result"
with rasterio.open(os.path.join(parent, "CBH_meter.tif")) as src:
    cbh_bnd = src.read(1, masked=True)

# %%
plt.hist(cbh_bnd, bins=50, density=True, color='gray', alpha=0.6, label="CBH")
